# %%
print("Hello, world!")

# %%
# %fs ls

# %%
# Create table if not exists
spark.sql("""
CREATE TABLE IF NOT EXISTS sample_table (
    id INT,
    name STRING,
    category STRING,
    amount DOUBLE,
    quantity INT,
    status STRING,
    created_date DATE,
    updated_date TIMESTAMP,
    country STRING,
    city STRING,
    remarks STRING,
    is_active BOOLEAN
)
""")

# Insert 20 sample rows
spark.sql("""
INSERT INTO sample_table VALUES
(1 , 'Item A', 'Type1', 120.50, 10, 'NEW', current_date(), current_timestamp(), 'USA', 'New York', 'First batch', true),
(2 , 'Item B', 'Type1', 89.99 , 5 , 'PENDING', current_date(), current_timestamp(), 'USA', 'Chicago', 'Check quality', true),
(3 , 'Item C', 'Type2', 150.00, 12, 'NEW', current_date(), current_timestamp(), 'Canada', 'Toronto', 'Priority', true),
(4 , 'Item D', 'Type2', 45.75 , 7 , 'APPROVED', current_date(), current_timestamp(), 'Canada', 'Vancouver', 'OK', true),
(5 , 'Item E', 'Type3', 200.00, 3 , 'REJECTED', current_date(), current_timestamp(), 'UK', 'London', 'Review needed', false),
(6 , 'Item F', 'Type1', 33.20 , 15, 'NEW', current_date(), current_timestamp(), 'UK', 'Manchester', 'None', true),
(7 , 'Item G', 'Type2', 78.10 , 8 , 'PENDING', current_date(), current_timestamp(), 'Germany', 'Berlin', 'Batch B', true),
(8 , 'Item H', 'Type3', 99.99 , 4 , 'NEW', current_date(), current_timestamp(), 'Germany', 'Hamburg', 'Urgent', true),
(9 , 'Item I', 'Type1', 66.40 , 9 , 'APPROVED', current_date(), current_timestamp(), 'Japan', 'Tokyo', 'Standard', true),
(10, 'Item J', 'Type2', 170.00, 11, 'NEW', current_date(), current_timestamp(), 'Japan', 'Osaka', 'None', true),
(11, 'Item K', 'Type3', 245.75, 6 , 'REJECTED', current_date(), current_timestamp(), 'Australia', 'Sydney', 'Issue found', false),
(12, 'Item L', 'Type1', 58.60 , 14, 'NEW', current_date(), current_timestamp(), 'Australia', 'Melbourne', 'Stock in', true),
(13, 'Item M', 'Type2', 130.10, 20, 'PENDING', current_date(), current_timestamp(), 'Philippines', 'Manila', 'Local batch', true),
(14, 'Item N', 'Type2', 74.50 , 2 , 'NEW', current_date(), current_timestamp(), 'Philippines', 'Cebu', 'Monitor', true),
(15, 'Item O', 'Type3', 300.00, 1 , 'APPROVED', current_date(), current_timestamp(), 'India', 'Mumbai', 'High value', true),
(16, 'Item P', 'Type3', 110.30, 13, 'PENDING', current_date(), current_timestamp(), 'India', 'Delhi', 'QC needed', true),
(17, 'Item Q', 'Type1', 41.90 , 10, 'NEW', current_date(), current_timestamp(), 'France', 'Paris', 'Standard', true),
(18, 'Item R', 'Type1', 92.20 , 6 , 'REJECTED', current_date(), current_timestamp(), 'France', 'Lyon', 'Damaged', false),
(19, 'Item S', 'Type2', 255.00, 5 , 'APPROVED', current_date(), current_timestamp(), 'China', 'Beijing', 'Bulk', true),
(20, 'Item T', 'Type3', 18.75 , 16, 'NEW', current_date(), current_timestamp(), 'China', 'Shanghai', 'OK', true)
""")

# Verify the data
display(spark.sql("SELECT * FROM sample_table"))
