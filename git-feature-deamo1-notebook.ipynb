# %%
print("Hello, world!")

# %%
# %fs ls

# %%
# %sql
-- Create the table
CREATE OR REPLACE TABLE sample_table (
    id INT,
    first_name STRING,
    last_name STRING,
    age INT,
    country STRING,
    city STRING,
    department STRING,
    salary DOUBLE,
    is_active BOOLEAN,
    join_date DATE,
    rating DOUBLE,
    comments STRING,
    utc_ts TIMESTAMP
);

-- Insert 20 rows
INSERT INTO sample_table VALUES
(1, 'John', 'Doe', 30, 'USA', 'New York', 'Sales', 5200.50, true, '2022-01-10', 4.5, 'Good employee', current_timestamp()),
(2, 'Alice', 'Smith', 28, 'UK', 'London', 'HR', 4800.00, true, '2021-03-15', 4.2, 'Reliable', current_timestamp()),
(3, 'Robert', 'Johnson', 35, 'Canada', 'Toronto', 'IT', 6100.75, true, '2020-11-20', 4.7, 'Excellent', current_timestamp()),
(4, 'Emily', 'Brown', 26, 'Australia', 'Sydney', 'Finance', 4500.30, false, '2023-04-01', 4.1, 'On leave', current_timestamp()),
(5, 'Michael', 'Lee', 40, 'USA', 'Chicago', 'Operations', 7000.00, true, '2019-07-18', 4.8, 'Top performer', current_timestamp()),
(6, 'Sophia', 'Wilson', 31, 'Germany', 'Berlin', 'Marketing', 5500.00, true, '2022-09-05', 4.3, 'Consistent', current_timestamp()),
(7, 'Daniel', 'Martinez', 29, 'Spain', 'Madrid', 'Sales', 4700.25, true, '2021-08-12', 4.0, 'Good', current_timestamp()),
(8, 'Olivia', 'Davis', 34, 'USA', 'Houston', 'IT', 6800.40, true, '2020-06-22', 4.6, 'Very good', current_timestamp()),
(9, 'James', 'Garcia', 27, 'Mexico', 'Monterrey', 'Support', 4100.00, false, '2023-02-14', 3.9, 'Average', current_timestamp()),
(10, 'Ava', 'Miller', 33, 'France', 'Paris', 'Design', 5300.90, true, '2021-10-30', 4.4, 'Creative', current_timestamp()),
(11, 'Ethan', 'Taylor', 38, 'Italy', 'Rome', 'Finance', 7200.20, true, '2019-02-10', 4.9, 'Outstanding', current_timestamp()),
(12, 'Mia', 'Anderson', 25, 'USA', 'Seattle', 'HR', 4600.10, true, '2022-12-01', 4.0, 'New hire', current_timestamp()),
(13, 'Lucas', 'Thomas', 32, 'Netherlands', 'Amsterdam', 'IT', 6400.00, true, '2020-03-05', 4.5, 'Solid', current_timestamp()),
(14, 'Isabella', 'Jackson', 29, 'Brazil', 'Sao Paulo', 'Support', 4200.35, false, '2023-01-20', 3.8, 'OK', current_timestamp()),
(15, 'Henry', 'White', 36, 'Japan', 'Tokyo', 'Sales', 5900.50, true, '2018-11-15', 4.7, 'High achiever', current_timestamp()),
(16, 'Charlotte', 'Harris', 30, 'South Korea', 'Seoul', 'Marketing', 5600.75, true, '2021-05-07', 4.2, 'Reliable', current_timestamp()),
(17, 'Benjamin', 'Clark', 41, 'India', 'Bangalore', 'IT', 7100.00, true, '2017-09-25', 4.8, 'Expert', current_timestamp()),
(18, 'Amelia', 'Lewis', 28, 'Singapore', 'Singapore', 'Design', 5400.80, true, '2020-12-10', 4.3, 'Creative', current_timestamp()),
(19, 'Noah', 'Robinson', 35, 'UAE', 'Dubai', 'Operations', 6900.65, true, '2019-04-03', 4.6, 'Very dependable', current_timestamp()),
(20, 'Harper', 'Walker', 27, 'USA', 'Miami', 'Support', 4300.20, false, '2023-07-19', 3.7, 'Still improving', current_timestamp());

# %%
# %sql
SELECT * FROM sample_table;
